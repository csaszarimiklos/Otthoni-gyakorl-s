# %%
import time
import threading
from datetime import datetime
import pandas 
import warnings
import numpy
# Out:
# Running cells with 'Python 3.12.13' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/usr/bin/python3.12 -m pip install ipykernel -U --user --force-reinstall'

# %%
from ibapi.client import EClient
from ibapi.wrapper import EWrapper
from ibapi.contract import Contract
from ibapi.order import Order
from ibapi.common import BarData
# Out:
# Running cells with 'Python 3.12.13' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/usr/bin/python3.12 -m pip install ipykernel -U --user --force-reinstall'

# %%
import pandas_datareader.data as web
start = datetime(2026,4,9)
end = datetime(2026,4,10)
stock_ = web.DataReader("MSFT","yahoo",start,end)
print(stock_.head())
# Out:
# Running cells with 'Python 3.12.13' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/usr/bin/python3.12 -m pip install ipykernel -U --user --force-reinstall'

# %%
# class trading_app(EClient,EWrapper):
#     def __init__(self) ->None:
#         EClient.__init__(self,self)
#         self.data:Dict[int,pandas.DataFrame] = {}6˛/
