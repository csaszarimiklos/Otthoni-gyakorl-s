# %%
from collections import defaultdict
import os

path = "/home/csaszi/IDUNADA/idunada_20250116.csv"
with os.scandir(path) as mappak:
    for sorok in mappak:
        print(sorok)

# %% [markdown]
# Helloka nyaloka

# %% [markdown]
# hát itt mi változott
